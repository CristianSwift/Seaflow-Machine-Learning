# %% [markdown]
# ![Python logo](https://cmap.readthedocs.io/en/latest/_static/CMAP_logos/CMAP_logo_High_Res.png)
# # In this notebook we will download SeaFlow and enviormental data Using [Simons CMAP](https://simonscmap.com).

# %% [markdown]
# Below are the datasets that will be used
# The End goalEnd goal is to create a dataset that has these variables below.
#
#
#
# #### SeaFlow:
#  - time
#  - lat
#  - lon
#  - biomass
#  - CruiseName
#
#
# In this notebook we will also use <u> depth</u>, and <u>cruise</u> to match with other avalaible CMAP dataframes.
#
#
# #### Mercator Pisces Biogeochemistry blended observations and model:
#  - NO3
#  - PO4
#  - Fe
#  - Si
#  - Alk
#
#
# #### NOAA Satellite Sea Surface Temperature:
#  - sst
#
#
# #### SMAP Satellite Sea Surface Salinity:
#  - sss
#
#
# #### Copernicus Satellite SSH derived current speed:
#  - ugos
#  - vgos

# %% [markdown]
# # Loading Functions

# %%
import pandas as pd
import numpy as np

# %%
# Set a working directory
#!pip install GitPython
import git
import os

repo = git.Repo('.', search_parent_directories=True)


os.chdir(repo.working_tree_dir)

# %% [markdown]
# ## Creating Real Time data set
# ### Datetime is in UTC

# %% [markdown]
# ## The Covariate Seaflow dataset is all cruises that SeaFlow has been run on as of 2023

# %%
import pandas as pd
covari_path = 'data_ingest/data/original/SeaFlow_cmap_v1/SeaFlow_cmap_v1.6.xlsx'
#covari = pd.read_excel(covari_path, sheet_name=0)
#changing column names to be earier to read
covari_cols = ['time', 'lat',
       'lon', 'depth', 'cruise', 'abundance_prochloro', 'abundance_synecho',
       'abundance_picoeuk', 'abundance_croco', 'diam_prochloro', 'diam_synecho', 
       'diam_picoeuk', 'diam_croco',  'Qc_prochloro', 'Qc_synecho', 'Qc_picoeuk', 'Qc_croco', 
       'biomass_prochloro', 'biomass_synecho', 'biomass_picoeuk', 'biomass_croco']

#reading in the xlsx to a pandas df
covari = (pd
          .read_excel(covari_path, sheet_name=0, names=covari_cols)
          #need to get rid of the first 2 rosw as they are a repeat when loaded as such
          .tail(-2)
         )

covari.head(3)
# Out:
#                  time      lat       lon  depth  cruise  abundance_prochloro  \
# 2 2010-05-21 20:17:20  44.2505 -124.1677      5  W1005A             0.082249
# 3 2010-05-21 20:23:20  44.2519 -124.1685      5  W1005A             0.164716
# 4 2010-05-21 20:26:20  44.2519 -124.1687      5  W1005A             0.041195
#
#    abundance_synecho  abundance_picoeuk  abundance_croco  diam_prochloro  ...  \
# 2           2.352316           5.753303         0.045237        1.058705  ...
# 3           2.437801           5.583881         0.037061        0.793225  ...
# 4           2.442870           5.487189         0.028837        0.655232  ...
#
#    diam_picoeuk  diam_croco  Qc_prochloro  Qc_synecho  Qc_picoeuk  Qc_croco  \
# 2      0.826935    1.744986      0.208296    0.038762    0.091634  0.629223
# 3      0.826297    1.527685      0.082608    0.038834    0.091452  0.446465
# 4      0.836938    1.575126      0.050267    0.039896    0.094522  0.483121
#
#    biomass_prochloro  biomass_synecho  biomass_picoeuk  biomass_croco
# 2           0.017132         0.091180         0.527201       0.028464
# 3           0.013607         0.094669         0.510656       0.016547
# 4           0.002071         0.097461         0.518658       0.013932
#
# [3 rows x 21 columns]

# %%
#this cruise does not have lat/lon values so it needs to be removed
covari = covari[covari['cruise'] != 'KOK1512']

# %%
def ChangeObjectTypes(df):
    """
    Changing the object types so that it works best for CMAP colocalizatin of data
    """
    for column in df:
        if column == 'PopulationName' or column == 'cruise' or column == 'time':
            #changing to string
            df[column] = df[column].astype(str)
            
        else:
            #changing to numeric type
            df[column] = pd.to_numeric(df[column])
    return df
covari = ChangeObjectTypes(covari)

# %% [markdown]
# ## Keeping only the data varaibles that we will be using for the machine learning model

# %%
covari = (covari[['time', 'lat',
            'lon', 'depth', 'cruise', 'abundance_prochloro', 'abundance_synecho',
            'abundance_picoeuk', 'abundance_croco', 'diam_prochloro', 'diam_synecho', 
            'diam_picoeuk', 'diam_croco',  'Qc_prochloro', 'Qc_synecho', 'Qc_picoeuk', 'Qc_croco', 
            'biomass_prochloro', 'biomass_synecho', 'biomass_picoeuk', 'biomass_croco']]
          .dropna()
          .reset_index(drop=True)
         )
covari
# Out:
#                        time      lat       lon  depth   cruise  \
# 0       2010-05-21 20:17:20  44.2505 -124.1677      5   W1005A
# 1       2010-05-21 20:23:20  44.2519 -124.1685      5   W1005A
# 2       2010-05-21 20:26:20  44.2519 -124.1687      5   W1005A
# 3       2010-05-21 20:29:20  44.2519 -124.1686      5   W1005A
# 4       2010-05-21 20:38:20  44.2530 -124.1752      5   W1005A
# ...                     ...      ...       ...    ...      ...
# 121471  2012-02-06 03:57:38  34.5645 -122.2759      5  Tokyo_4
# 121472  2012-02-06 04:06:39  34.5572 -122.2139      5  Tokyo_4
# 121473  2012-02-06 04:24:40  34.5421 -122.0920      5  Tokyo_4
# 121474  2012-02-06 04:27:40  34.5399 -122.0718      5  Tokyo_4
# 121475  2012-02-06 04:33:41  34.5355 -122.0314      5  Tokyo_4
#
#         abundance_prochloro  abundance_synecho  abundance_picoeuk  \
# 0                  0.082249           2.352316           5.753303
# 1                  0.164716           2.437801           5.583881
# 2                  0.041195           2.442870           5.487189
# 3                  0.123568           2.397221           5.465828
# 4                  0.123396           2.644784           5.569264
# ...                     ...                ...                ...
# 121471           199.265903         286.071037         209.833832
# 121472           185.432911         254.462842         199.292507
# 121473           165.296363         235.585959         191.344464
# 121474           146.827747         204.563909         190.944719
# 121475           194.706692         265.023318         206.919565
#
#         abundance_croco  diam_prochloro  ...  diam_picoeuk  diam_croco  \
# 0              0.045237        1.058705  ...      0.826935    1.744986
# 1              0.037061        0.793225  ...      0.826297    1.527685
# 2              0.028837        0.655232  ...      0.836938    1.575126
# 3              0.057665        0.863134  ...      0.828218    2.163342
# 4              0.024679        0.756068  ...      0.846435    1.430712
# ...                 ...             ...  ...           ...         ...
# 121471         0.090759        0.438957  ...      0.930074    3.097573
# 121472         0.091798        0.435216  ...      0.920438    0.732544
# 121473         0.092170        0.437831  ...      0.903773    1.965274
# 121474         0.092022        0.445211  ...      0.910481    3.351962
# 121475         0.092375        0.438957  ...      0.897130    3.126999
#
#         Qc_prochloro  Qc_synecho  Qc_picoeuk  Qc_croco  biomass_prochloro  \
# 0           0.208296    0.038762    0.091634  0.629223           0.017132
# 1           0.082608    0.038834    0.091452  0.446465           0.013607
# 2           0.050267    0.039896    0.094522  0.483121           0.002071
# 3           0.102344    0.037872    0.092002  1.100616           0.012646
# 4           0.072723    0.039015    0.097314  0.377199           0.008974
# ...              ...         ...         ...       ...                ...
# 121471      0.017883    0.029180    0.124096  2.765768           3.563395
# 121472      0.017492    0.029180    0.120805  0.067027           3.243594
# 121473      0.017764    0.028334    0.115243  0.855090           2.936403
# 121474      0.018547    0.028721    0.117462  3.390411           2.723253
# 121475      0.017883    0.028398    0.113070  2.834074           3.481865
#
#         biomass_synecho  biomass_picoeuk  biomass_croco
# 0              0.091180         0.527201       0.028464
# 1              0.094669         0.510656       0.016547
# 2              0.097461         0.518658       0.013932
# 3              0.090787         0.502864       0.063467
# 4              0.103186         0.541965       0.009309
# ...                 ...              ...            ...
# 121471         8.347600        26.039451       0.251017
# 121472         7.425268        24.075548       0.006153
# 121473         6.675133        22.051099       0.078813
# 121474         5.875356        22.428844       0.311991
# 121475         7.526214        23.396386       0.261797
#
# [121476 rows x 21 columns]

# %%
covari.dtypes
# Out:
# time                    object
# lat                    float64
# lon                    float64
# depth                    int64
# cruise                  object
# abundance_prochloro    float64
# abundance_synecho      float64
# abundance_picoeuk      float64
# abundance_croco        float64
# diam_prochloro         float64
# diam_synecho           float64
# diam_picoeuk           float64
# diam_croco             float64
# Qc_prochloro           float64
# Qc_synecho             float64
# Qc_picoeuk             float64
# Qc_croco               float64
# biomass_prochloro      float64
# biomass_synecho        float64
# biomass_picoeuk        float64
# biomass_croco          float64
# dtype: object

# %% [markdown]
# # Using SimonCMAP to gather additional features

# %% [markdown]
# #### First installing and importing pycmap

# %%
# !pip install pycmap
import pycmap
# Out:
# Collecting pycmap
#   Using cached pycmap-0.2.19-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: numpy in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from pycmap) (1.26.0)
# Requirement already satisfied: pandas in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from pycmap) (2.1.1)
# Requirement already satisfied: scipy in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from pycmap) (1.11.3)
# Collecting bokeh (from pycmap)
#   Using cached bokeh-3.3.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from pycmap) (3.8.0)
# Collecting cmocean (from pycmap)
#   Using cached cmocean-3.1.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting tqdm (from pycmap)
#   Using cached tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: folium in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from pycmap) (0.14.0)
# Collecting colorama (from pycmap)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: plotly in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from pycmap) (5.9.0)
# Requirement already satisfied: Jinja2>=2.9 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from bokeh->pycmap) (3.1.3)
# Requirement already satisfied: contourpy>=1 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from bokeh->pycmap) (1.2.0)
# Requirement already satisfied: packaging>=16.8 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from bokeh->pycmap) (23.1)
# Requirement already satisfied: pillow>=7.1.0 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from bokeh->pycmap) (10.2.0)
# Requirement already satisfied: PyYAML>=3.10 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from bokeh->pycmap) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from bokeh->pycmap) (6.3.3)
# Requirement already satisfied: xyzservices>=2021.09.1 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from bokeh->pycmap) (2022.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from pandas->pycmap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from pandas->pycmap) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from pandas->pycmap) (2023.3)
# Requirement already satisfied: branca>=0.6.0 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from folium->pycmap) (0.6.0)
# Requirement already satisfied: requests in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from folium->pycmap) (2.31.0)
# Requirement already satisfied: cycler>=0.10 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from matplotlib->pycmap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from matplotlib->pycmap) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from matplotlib->pycmap) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from matplotlib->pycmap) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from matplotlib->pycmap) (6.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from plotly->pycmap) (8.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->pycmap) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh->pycmap) (2.1.3)
# Requirement already satisfied: six>=1.5 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->pycmap) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from requests->folium->pycmap) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from requests->folium->pycmap) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from requests->folium->pycmap) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bakervanb/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages (from requests->folium->pycmap) (2024.2.2)
# Using cached pycmap-0.2.19-py3-none-any.whl (47 kB)
# Using cached bokeh-3.3.4-py3-none-any.whl (6.8 MB)
# Using cached cmocean-3.1.3-py3-none-any.whl (222 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, colorama, cmocean, bokeh, pycmap
# Successfully installed bokeh-3.3.4 cmocean-3.1.3 colorama-0.4.6 pycmap-0.2.19 tqdm-4.66.2

# %% [markdown]
# #### Setting API

# %%
api = pycmap.API(token='<6e1eb1d3-d364-4dfb-9121-8c23369dbbbe>')

# %% [markdown]
# ### Prepping covariate data for colocalization using Simon's CMAP

# %%
covari.head(3)
covari['time'] = pd.to_datetime(covari['time'])
import numpy as np
# Separate numeric and object (string) columns
covari.set_index('time', inplace=True)
covari_cmap_numeric = covari.select_dtypes(include=[np.number])
covari_cmap_non_numeric = covari.select_dtypes(exclude=[np.number])

# Average numeric columns by hour, take first data point in each hour for object columns
covari_cmap_numeric_hourly = covari_cmap_numeric.resample('H').mean()
covari_cmap_non_numeric_hourly = covari_cmap_non_numeric.resample('H').first()

# Recombine
covari_cmap_hourly = pd.concat([covari_cmap_non_numeric_hourly, covari_cmap_numeric_hourly], axis=1)
covari_cmap_hourly.dropna(inplace=True)
covari_cmap_hourly.reset_index(inplace=True)
covari_cmap_hourly.head(3)
# Out:
#                  time cruise        lat         lon  depth  \
# 0 2009-11-07 23:00:00  TN243  47.455531 -122.408963    5.0
# 1 2009-11-08 00:00:00  TN243  47.426100 -122.396100    5.0
# 2 2009-11-08 17:00:00  TN243  47.343433 -122.540133    5.0
#
#    abundance_prochloro  abundance_synecho  abundance_picoeuk  abundance_croco  \
# 0             0.296867           0.181126           6.632747         0.261147
# 1             0.068834           0.178967           4.130016         0.199617
# 2             0.068775           0.090553           1.940754         0.111194
#
#    diam_prochloro  ...  diam_picoeuk  diam_croco  Qc_prochloro  Qc_synecho  \
# 0        0.701349  ...      1.927030    5.283986      0.060232    0.198430
# 1        0.645218  ...      1.971641    6.573950      0.048309    0.253520
# 2        0.706921  ...      1.998109    5.294829      0.061427    0.206915
#
#    Qc_picoeuk   Qc_croco  biomass_prochloro  biomass_synecho  biomass_picoeuk  \
# 0    0.813686  11.023746           0.017932         0.035915         5.395694
# 1    0.862262  19.274369           0.003325         0.045372         3.561155
# 2    0.895059  11.140859           0.004225         0.018923         1.720945
#
#    biomass_croco
# 0       2.877982
# 1       3.847500
# 2       1.247962
#
# [3 rows x 21 columns]

# %%
covari_cmap_hourly.tail(10)
covari = covari_cmap_hourly
covari.head(3)
covari['time'] = covari['time'].dt.strftime('%Y-%m-%d %H:%M:%S')

# %% [markdown]
# ## Querying CMAP
# This takes ~2 hours, so only run if you need new data.  The repository already contains this data so running this function is not needed for the model to run

# %%
targets = {
        
        # Darwin Biogeochemistry Climatology Model
        "tblDarwin_Nutrient_Climatology": {
                          "variables": ["ALK_darwin_clim"],
            # Tolerance varaibles/order: temporal [days], meridional [deg], zonal [deg], and vertical [m]
                          "tolerances": [1, 0.5, 0.5, 5]
                         },

        # CMAP sea surface salinity
        "tblSSS_NRT_cl1": {
                          "variables": ['sss_smap'],
            # Tolerance varaibles/order: temporal [days], meridional [deg], zonal [deg], and vertical [m]
                          "tolerances": [7, 1, 1, 6]
                         },
        # CMAP sea surface temperature
        "tblSST_AVHRR_OI_NRT": { "variables": ['sst'],
            # Tolerance varaibles/order: temporal [days], meridional [deg], zonal [deg], and vertical [m]
                          "tolerances": [1, 0.5, 0.5, 5]
                         },
        # CMAP SSH velocity
        "tblAltimetry_REP_Signal": { "variables": ['ugos', 'vgos'],
                        # Tolerance varaibles/order: temporal [days], meridional [deg], zonal [deg], and vertical [m]
                          "tolerances": [1, 0.5, 0.5, 5]
                         },
        # Pisces 2011-19
        "tblPisces_NRT": { "variables": ['Fe', 'O2', 'NO3', 'PO4', 'Si'],
                        # Tolerance varaibles/order: temporal [days], meridional [deg], zonal [deg], and vertical [m]
                          "tolerances": [7, 1, 1, 5]
                         },
        # Pisces 2019-21
        "tblPisces_Forecast": { "variables": ['fe', 'o2', 'no3', 'po4', 'si'],
                        # Tolerance varaibles/order: temporal [days], meridional [deg], zonal [deg], and vertical [m]
                          "tolerances": [1, 0.5, 0.5, 5]
                         },
        # Pisces 2020-24
        "tblPisces_Forecast_cl1": { "variables": ['fe', 'o2', 'no3', 'po4', 'si'],
                        # Tolerance varaibles/order: temporal [days], meridional [deg], zonal [deg], and vertical [m]
                          "tolerances": [1, 0.5, 0.5, 5]
                         },

        }


source = covari

covari_cmap = pycmap.Sample(
              source=source, 
              targets=targets, 
              replaceWithMonthlyClimatolog=False
             )
# Out:
# Gathering metadata ....
# Sampling starts
# Sampling tblPisces_Forecast_cl1 ... 8926 / 11144
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CMAP_fe_tblPisces_Forecast'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 47
#       1 targets = {
#       2
#       3         # Darwin Biogeochemistry Climatology Model
#    (...)
#      41
#      42         }
#      45 source = covari
# ---> 47 covari_cmap = pycmap.Sample(
#      48               source=source,
#      49               targets=targets,
#      50               replaceWithMonthlyClimatolog=False
#      51              )
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages/pycmap/sample.py:160, in Sample(source, targets, replaceWithMonthlyClimatolog, servers)
#     158 with concurrent.futures.ThreadPoolExecutor() as executor:
#     159     futureObjs = executor.map(match, dfs, [api] * len(dfs), [targets] * len(dfs), list(range(len(dfs))), [len(dfs)] * len(dfs), [replaceWithMonthlyClimatolog]*len(dfs), [servers] * len(dfs))
# --> 160     for fo in futureObjs:
#     161         if len(colocalizedList) < 1: columns = list(fo.columns)
#     162         colocalizedList.append(fo.values.tolist()[0])
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/concurrent/futures/_base.py:609, in Executor.map.<locals>.result_iterator()
#     606 while fs:
#     607     # Careful not to keep a reference to the popped future
#     608     if timeout is None:
# --> 609         yield fs.pop().result()
#     610     else:
#     611         yield fs.pop().result(end_time - time.monotonic())
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/concurrent/futures/_base.py:446, in Future.result(self, timeout)
#     444     raise CancelledError()
#     445 elif self._state == FINISHED:
# --> 446     return self.__get_result()
#     447 else:
#     448     raise TimeoutError()
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages/pycmap/sample.py:118, in match(df, api, targets, rowIndex, totalRows, replaceWithMonthlyClimatolog, servers)
#     116         matchedEnv = api.query(query, servers=servers)
#     117         if len(matchedEnv)>0:
# --> 118             for v in env["aliases"]: df.at[0, v] = matchedEnv.iloc[0][v]
#     119 return df
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages/pandas/core/series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages/pandas/core/series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'CMAP_fe_tblPisces_Forecast'

# %%
covari_cmap.head(10)
# Out:
#                    time  cruise        lat         lon  depth  \
# 28  2010-05-21 18:00:00  W1005A  44.493300 -124.136800    5.0
# 29  2010-05-21 20:00:00  W1005A  44.251625 -124.195262    5.0
# 30  2010-05-21 21:00:00  W1005A  44.252489 -124.252939    5.0
# 31  2010-05-21 22:00:00  W1005A  44.252175 -124.290925    5.0
# 32  2010-05-21 23:00:00  W1005A  44.250991 -124.456800    5.0
# 33  2010-05-22 00:00:00  W1005A  44.251764 -124.711009    5.0
# 34  2010-05-22 01:00:00  W1005A  44.252125 -124.834563    5.0
# 35  2010-05-22 02:00:00  W1005A  44.251705 -124.974795    5.0
# 36  2010-05-22 03:00:00  W1005A  44.251595 -125.150547    5.0
# 37  2010-05-22 04:00:00  W1005A  44.248485 -125.165160    5.0
#
#     abundance_prochloro  abundance_synecho  abundance_picoeuk  \
# 28             0.246577           1.652478          13.346651
# 29             0.102905           2.733110           5.297041
# 30             0.086831           3.083692           5.410113
# 31             0.143867           2.961071           6.720226
# 32             0.299187           4.599585           6.459321
# 33             0.636155           3.779168           4.939703
# 34             0.411412           3.605853           6.233767
# 35             0.643085           4.429017          10.323529
# 36             0.194922           2.900974           7.308691
# 37             0.404941           2.785428           8.015600
#
#     abundance_croco  diam_prochloro  ...  CMAP_fe_tblPisces_Forecast  \
# 28         0.141894        0.907278  ...                         NaN
# 29         0.039618        0.724296  ...                         NaN
# 30         0.061919        0.869899  ...                         NaN
# 31         0.109911        0.982521  ...                         NaN
# 32         0.128636        0.878229  ...                         NaN
# 33         0.034048        0.587510  ...                         NaN
# 34         0.029839        0.752117  ...                         NaN
# 35         0.024465        0.639234  ...                         NaN
# 36         0.019701        0.887000  ...                         NaN
# 37         0.017269        0.697642  ...                         NaN
#
#     CMAP_o2_tblPisces_Forecast  CMAP_no3_tblPisces_Forecast  \
# 28                         NaN                          NaN
# 29                         NaN                          NaN
# 30                         NaN                          NaN
# 31                         NaN                          NaN
# 32                         NaN                          NaN
# 33                         NaN                          NaN
# 34                         NaN                          NaN
# 35                         NaN                          NaN
# 36                         NaN                          NaN
# 37                         NaN                          NaN
#
#     CMAP_po4_tblPisces_Forecast  CMAP_si_tblPisces_Forecast  \
# 28                          NaN                         NaN
# 29                          NaN                         NaN
# 30                          NaN                         NaN
# 31                          NaN                         NaN
# 32                          NaN                         NaN
# 33                          NaN                         NaN
# 34                          NaN                         NaN
# 35                          NaN                         NaN
# 36                          NaN                         NaN
# 37                          NaN                         NaN
#
#     CMAP_fe_tblPisces_Forecast_cl1  CMAP_o2_tblPisces_Forecast_cl1  \
# 28                             NaN                             NaN
# 29                             NaN                             NaN
# 30                             NaN                             NaN
# 31                             NaN                             NaN
# 32                             NaN                             NaN
# 33                             NaN                             NaN
# 34                             NaN                             NaN
# 35                             NaN                             NaN
# 36                             NaN                             NaN
# 37                             NaN                             NaN
#
#     CMAP_no3_tblPisces_Forecast_cl1  CMAP_po4_tblPisces_Forecast_cl1  \
# 28                              NaN                              NaN
# 29                              NaN                              NaN
# 30                              NaN                              NaN
# 31                              NaN                              NaN
# 32                              NaN                              NaN
# 33                              NaN                              NaN
# 34                              NaN                              NaN
# 35                              NaN                              NaN
# 36                              NaN                              NaN
# 37                              NaN                              NaN
#
#     CMAP_si_tblPisces_Forecast_cl1
# 28                             NaN
# 29                             NaN
# 30                             NaN
# 31                             NaN
# 32                             NaN
# 33                             NaN
# 34                             NaN
# 35                             NaN
# 36                             NaN
# 37                             NaN
#
# [10 rows x 41 columns]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Checking for NaN values

# %%
covari_cmap.isna().sum()
# Out:
# time                                                      0
# cruise                                                    0
# lat                                                       0
# lon                                                       0
# depth                                                     0
# abundance_prochloro                                       0
# abundance_synecho                                         0
# abundance_picoeuk                                         0
# abundance_croco                                           0
# diam_prochloro                                            0
# diam_synecho                                              0
# diam_picoeuk                                              0
# diam_croco                                                0
# Qc_prochloro                                              0
# Qc_synecho                                                0
# Qc_picoeuk                                                0
# Qc_croco                                                  0
# biomass_prochloro                                         0
# biomass_synecho                                           0
# biomass_picoeuk                                           0
# biomass_croco                                             0
# CMAP_ALK_darwin_clim_tblDarwin_Nutrient_Climatology       4
# CMAP_sss_tblSSS_NRT                                    4219
# CMAP_sst_tblSST_AVHRR_OI_NRT                              5
# CMAP_ugos_tblAltimetry_REP_Signal                         5
# CMAP_vgos_tblAltimetry_REP_Signal                         5
# CMAP_Fe_tblPisces_NRT                                  8901
# CMAP_O2_tblPisces_NRT                                  8901
# CMAP_NO3_tblPisces_NRT                                 8901
# CMAP_PO4_tblPisces_NRT                                 8901
# CMAP_Si_tblPisces_NRT                                  8901
# CMAP_fe_tblPisces_Forecast                             8441
# CMAP_o2_tblPisces_Forecast                             8441
# CMAP_no3_tblPisces_Forecast                            8441
# CMAP_po4_tblPisces_Forecast                            8441
# CMAP_si_tblPisces_Forecast                             8441
# CMAP_fe_tblPisces_Forecast_cl1                         7932
# CMAP_o2_tblPisces_Forecast_cl1                         7932
# CMAP_no3_tblPisces_Forecast_cl1                        7932
# CMAP_po4_tblPisces_Forecast_cl1                        7932
# CMAP_si_tblPisces_Forecast_cl1                         7932
# dtype: int64
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#removing cruises with nan values
covari_cmapp = covari_cmap[covari_cmap['cruise'] != 'TN243']
covari_cmapp = covari_cmapp[covari_cmapp['cruise'] != 'TN291']
covari_cmap = covari_cmapp
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Saving as a CSV

# %%
#saving as a CSV file
covari_cmap.to_csv('data_ingest/data/modified/Seaflow_covariates_CMAP.csv', index=False)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
