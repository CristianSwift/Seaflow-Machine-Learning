# %% [markdown]
# # THIS IS A WIP DO NOT RUN

# %%
# Set a working directory
#!pip install GitPython
import git
import os

repo = git.Repo('.', search_parent_directories=True)


os.chdir(repo.working_tree_dir)

# %%
import pycmap
import pandas as pd
api = pycmap.API(token='<6e1eb1d3-d364-4dfb-9121-8c23369dbbbe>')

# %%
predictors = pd.read_csv('data_ingest/data/original/predictors.csv')

# %%
api.head('tblDarwin_Plankton_Climatology')
# Out:
#    depth    lat    lon  month  prokaryote_c01_darwin_clim  \
# 0     65  16.25  18.25      1                         NaN
# 1     65  16.25  18.75      1                         NaN
# 2     65  16.25  19.25      1                         NaN
# 3     65  16.25  19.75      1                         NaN
# 4     65  16.25  20.25      1                         NaN
#
#    prokaryote_c02_darwin_clim  picoeukaryote_c03_darwin_clim  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
#
#    picoeukaryote_c04_darwin_clim  cocco_c05_darwin_clim  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
#
#    cocco_c06_darwin_clim  ...  zooplankton_c42_darwin_clim  \
# 0                    NaN  ...                          NaN
# 1                    NaN  ...                          NaN
# 2                    NaN  ...                          NaN
# 3                    NaN  ...                          NaN
# 4                    NaN  ...                          NaN
#
#    zooplankton_c43_darwin_clim  zooplankton_c44_darwin_clim  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    zooplankton_c45_darwin_clim  zooplankton_c46_darwin_clim  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    zooplankton_c47_darwin_clim  zooplankton_c48_darwin_clim  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    zooplankton_c49_darwin_clim  zooplankton_c50_darwin_clim  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    zooplankton_c51_darwin_clim
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 55 columns]

# %%
#api.get_var_coverage( "tblDarwin_Nutrient_Climatology", 'prokaryote_c01_darwin_clim')
api.search_catalog('prokaryote_c01_darwin_clim')
# Out:
#                      Variable                      Table_Name  \
# 0  prokaryote_c01_darwin_clim  tblDarwin_Plankton_Climatology
#
#                          Long_Name     Unit   Make Sensor Process_Level  \
# 0  c01 concentration (climatology)  mmol C/  Model  Blend   Reprocessed
#
#       Study_Domain  Temporal_Resolution Spatial_Resolution  ...  \
# 0  Biogeochemistry  Monthly Climatology      1/2Â° X 1/2Â°  ...
#
#                     Data_Source                   Distributor  \
# 0  http://darwinproject.mit.edu  http://darwinproject.mit.edu
#
#                                  Dataset_Description  \
# 0  This version of the model is modified from Dut...
#
#                                    Acknowledgement  Dataset_ID   ID  \
# 0  Data provided by: http://darwinproject.mit.edu/          21  174
#
#    Visualize                                           Keywords  \
# 0          1  bio, biogeochem, biogeochemistry, biogo, blend...
#
#    Unstructured_Dataset_Metadata  Unstructured_Variable_Metadata
# 0                            NaN                             NaN
#
# [1 rows x 39 columns]

# %%
predictors.drop(columns=['time'], inplace=True)
predictors['month'] = 4

# %%
targets = {
        "tblDarwin_Plankton_Climatology": {
                          "variables": ["prokaryote_c01_darwin_clim"],
            # Tolerance varaibles/order: temporal [days], meridional [deg], zonal [deg], and vertical [m]
                          "tolerances": [20, 0.5, 0.5, 5]
                         }
        }


source = predictors

predictors_darwin = pycmap.Sample(
              source=source, 
              targets=targets, 
              replaceWithMonthlyClimatolog=False
             )
# Out:
# Gathering metadata ....
# Sampling starts
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 12
#       1 targets = {
#       2         "tblDarwin_Plankton_Climatology": {
#       3                           "variables": ["prokaryote_c01_darwin_clim"],
#    (...)
#       6                          }
#       7         }
#      10 source = predictors
# ---> 12 predictors_darwin = pycmap.Sample(
#      13               source=source,
#      14               targets=targets,
#      15               replaceWithMonthlyClimatolog=False
#      16              )
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages/pycmap/sample.py:160, in Sample(source, targets, replaceWithMonthlyClimatolog, servers)
#     158 with concurrent.futures.ThreadPoolExecutor() as executor:
#     159     futureObjs = executor.map(match, dfs, [api] * len(dfs), [targets] * len(dfs), list(range(len(dfs))), [len(dfs)] * len(dfs), [replaceWithMonthlyClimatolog]*len(dfs), [servers] * len(dfs))
# --> 160     for fo in futureObjs:
#     161         if len(colocalizedList) < 1: columns = list(fo.columns)
#     162         colocalizedList.append(fo.values.tolist()[0])
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/concurrent/futures/_base.py:609, in Executor.map.<locals>.result_iterator()
#     606 while fs:
#     607     # Careful not to keep a reference to the popped future
#     608     if timeout is None:
# --> 609         yield fs.pop().result()
#     610     else:
#     611         yield fs.pop().result(end_time - time.monotonic())
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages/pycmap/sample.py:104, in match(df, api, targets, rowIndex, totalRows, replaceWithMonthlyClimatolog, servers)
#     102 rowIndex = df.index.values[0]
#     103 df.reset_index(drop=True, inplace=True)
# --> 104 t= df.iloc[0]["time"]
#     105 lat = df.iloc[0]["lat"]
#     106 lon = df.iloc[0]["lon"]
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages/pandas/core/series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages/pandas/core/series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File ~/anaconda3/envs/machine-learning-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'time'

# %%
predictors.to_csv('data_ingest/data/original/predictors_darwin.csv', index=False)
