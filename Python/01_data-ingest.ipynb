# %% [markdown]
# ## This notebook will guide us through ingesting all downloaded/unmodifed dataframes

# %% [markdown]
# Functions to be used

# %%
import pandas as pd

# %%
seaflow_path = '/Users/cristianswift/Desktop/armbrust-lab/Seaflow-Machine-Learning/data/01-original/Seaflow_all_CMAP.csv'

seaflow = (pd
           .read_csv(seaflow_path,
                     parse_dates=[0], index_col = [0],
                    na_values="NaN")
           .reset_index()
          )
seaflow.head()
# Out:
#                  time      lat       lon  depth cruise  abundance_prochloro  \
# 0 2010-05-04 23:13:08  49.9424 -136.3091      5  TN248                  NaN
# 1 2010-05-04 23:16:08  49.9424 -136.3091      5  TN248                  NaN
# 2 2010-05-04 23:19:08  49.9424 -136.3091      5  TN248                  NaN
# 3 2010-05-04 23:22:08  49.9424 -136.3091      5  TN248                  NaN
# 4 2010-05-04 23:28:08  49.9424 -136.3091      5  TN248                  NaN
#
#    abundance_synecho  abundance_picoeuk  abundance_croco  diam_prochloro  ...  \
# 0           9.450561          42.470594         0.000000             NaN  ...
# 1           9.719664          44.614850         0.045525             NaN  ...
# 2           9.955824          44.106351         0.000000             NaN  ...
# 3          11.054114          43.395945         0.022792             NaN  ...
# 4           9.504259          40.182275         0.045584             NaN  ...
#
# ...

# %%
seaflow.columns
# Out:
# Index(['time', 'lat', 'lon', 'depth', 'cruise', 'abundance_prochloro',
#        'abundance_synecho', 'abundance_picoeuk', 'abundance_croco',
#        'diam_prochloro', 'diam_synecho', 'diam_picoeuk', 'diam_croco',
#        'Qc_prochloro', 'Qc_synecho', 'Qc_picoeuk', 'Qc_croco',
#        'biomass_prochloro', 'biomass_synecho', 'biomass_picoeuk',
#        'biomass_croco'],
#       dtype='object')
